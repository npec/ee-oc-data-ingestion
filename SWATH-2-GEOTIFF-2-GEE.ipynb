# %% [markdown]
# # Contents
# - [Purpose](#Purpose)
# - [Library import](#Library-import)
# - [Input params](#Input-params)
# - [Function definitions](#Function-definitions)
# - [EO Data Conversion Tool resampling](#EO-Data-Conversion-Tool-resampling)
# - [Join EO Data Conversion Tool files](#Join-EO-Data-Conversion-Tool-files)
# - [GCloud and manifest file](#GCloud-and-manifest-file)
# - [Build manifest and ingest files into GEE](#Build-manifest-and-ingest-files-into-GEE)
# ***

# %% [markdown]
# # Purpose
# [Return to the "Table of contents"](#Contents)
#
# Create Google Earth Engine ready GeoTIFFs from Level-2 data.
#
# The uploaded GeoTIFFs created by this notebook can be viewed in Google Earth Engine following the links
# 1. [MODIS/Aqua](https://ermaure.users.earthengine.app/view/swath-reprojection-modisa)
# 2. [SGLI/GCOM-C](https://ermaure.users.earthengine.app/view/swath-reprojection-sgli)
# 3. [Python vs. Data Conversion Tool](https://ermaure.users.earthengine.app/view/py-vs-dct)
#
#
# ***

# %% [markdown]
# # Library import
#
# [Return to the "Table of contents"](#Contents)
#
# Import all required modules below for the Level-2 resampling.
#
# ---

# %%
# !pip install netcdf4 pyresample gdal h5py pyproj
# Out:
# Requirement already satisfied: netcdf4 in c:\programdata\anaconda3\envs\ee\lib\site-packages (1.6.1)
# Requirement already satisfied: pyresample in c:\programdata\anaconda3\envs\ee\lib\site-packages (1.25.1)
# Requirement already satisfied: gdal in c:\programdata\anaconda3\envs\ee\lib\site-packages (3.5.2)
# Requirement already satisfied: h5py in c:\programdata\anaconda3\envs\ee\lib\site-packages (3.7.0)
# Requirement already satisfied: pyproj in c:\programdata\anaconda3\envs\ee\lib\site-packages (3.4.0)
# Requirement already satisfied: numpy>=1.9 in c:\programdata\anaconda3\envs\ee\lib\site-packages (from netcdf4) (1.23.3)
# Requirement already satisfied: cftime in c:\programdata\anaconda3\envs\ee\lib\site-packages (from netcdf4) (1.6.2)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\envs\ee\lib\site-packages (from pyresample) (6.0)
# Requirement already satisfied: pykdtree>=1.3.1 in c:\programdata\anaconda3\envs\ee\lib\site-packages (from pyresample) (1.3.5)
# Requirement already satisfied: configobj in c:\programdata\anaconda3\envs\ee\lib\site-packages (from pyresample) (5.0.6)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\envs\ee\lib\site-packages (from pyresample) (4.11.4)
# Requirement already satisfied: setuptools>=3.2 in c:\programdata\anaconda3\envs\ee\lib\site-packages (from pyresample) (65.4.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\envs\ee\lib\site-packages (from pyproj) (2022.9.24)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\ee\lib\site-packages (from configobj->pyresample) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\ee\lib\site-packages (from importlib-metadata->pyresample) (3.8.1)

# %%
import os
import subprocess
import time
from pathlib import Path
from pprint import pprint

import json
import numpy as np
from osgeo import osr, gdal

# %% [markdown]
# Local imports

# %%
import sys
sys.path.append('utils')

# %%
from utils.swathresample import SwathResample

# %% [markdown]
# # Input params
# [Return to the "Table of contents"](#Contents)
#
# Define the input file (netCDF4 or HDF5), output projection for the GeoTIFF file and the area id.
# We can also define here the [Google cloud bucket](https://cloud.google.com/storage/docs/gsutil), the [Earth Engine Asset](https://developers.google.com/earth-engine/guides/asset_manager).  The EE asset is where GeoTIFF file is uploaded to.
#
# Sample files are included `sample_data` folder or can be downloaded directly form the providers
# 1. https://oceandata.sci.gsfc.nasa.gov/ob/getfile/A2022125035500.L2_LAC_OC.nc
# 2. https://gportal.jaxa.jp/download/standard/GCOM-C/GCOM-C.SGLI/L2.OCEAN.IWPR/3/2022/05/03/GC1SG1_202205030152F05810_L2SG_IWPRQ_3000.h5
#
# ---

# %% [markdown]
# 1. The case of MODIS/Aqua sample file

# %%
# Smaple SGLI/GCOM-C files
INPUT_FILE = (Path('sample_data/A2022125035500.L2_LAC_OC.nc'), 
              Path('sample_data/GC1SG1_202205030152F05810_L2SG_IWPRQ_3000.h5'))
# Target projection
PROJ_NAME = 'laea'
# Projection area ID
# Output Path
OPATH = Path('result').absolute()
if not OPATH.is_dir():
    OPATH.mkdir(parents=True)
# GeoTIFF output
TRG_TIFF = (OPATH.joinpath('A2022125035500.L2_LAC_OC.tif'), 
            OPATH.joinpath('GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py.tif'))
# projection id
AREA_ID = 'nowpap_region'
# Google Cloud Bucket id
BUCKET = 'gs://YOUR_BUCKET_NAME'
# Giving a name of an existing asset will result in error
ASSET_ID = ''
# Asset name should not contain dots (.)
ASSET_NAME = 'A2022125035500_L2_LAC_OC', 'GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py'
# list will be updated with files to be uploaded
UPLOAD_TIF = []

# %% [markdown]
# # Function definitions
# [Return to the "Table of contents"](#Contents)
#
# Operations with Level-2 file
# `SwathResmaple` contains the following helper functions
# 1. `SwathResmaple.resample` - for swath resampling, accepts, data, cutoff and sequence number
# 2. `SwathResmaple.scale` - for data scaling into integer, accepts data and varname
# 3. `SwathResmaple.open` - open a new GeoTIFF file in write mode, accepts number os bands
# 4. `SwathResmaple.append` - append var(i) in the opened GeoTIFF, accept band sequence number and varname
# 5. `SwathResmaple.translate` - GDAL translate the created GeoTIFF
# 6. `SwathResmaple.close` - closes file, both netCDF4/HDF5 and GeoTIFF

# %%
def filt_keys(key):
    keep = 'chlor_a', 'CHLA', 'QA_flag', 'l2_flags'
    return key in keep

# %%
for src, dst in zip(INPUT_FILE, TRG_TIFF):
    with SwathResample(src, trg_tif=dst, srs=PROJ_NAME, area_id=AREA_ID) as fid:
    
        # get the spatial resolution from file metadata
        roi = fid.spatial_resolution()
        print(f'SpatialResolution: {roi}')
        # in the case of SGLI pass two files, since CHL and Rrs are in separate files
        keys = list(filter(filt_keys, fid.get_keys()))

        # joined = '\n\t'.join(keys)
        # print(f'Mapping variables\n\t{joined}')

        # open GeoTIFF file
        fid.open(bands=len(keys))

        # to avoid memory errors, especially with SGLI 250 m, process one variable at a time
        for i, key in enumerate(keys):
            # Read data from file
            sds = fid.get_data(key=key)
            # Pyresample, use twice the resolution. 
            # compansate for the decrease in resolution towards swath edge
            res = fid.resample(data=sds, i=i, roi=roi*2, key=key)
            # Scale data to int
            fid.data = fid.scale(key=key, data=res)
            # output result in GeoTIFFe
            fid.append(band=i+1, key=key)

        # translate the tif
        fid.translate()
        # There is temporary file created internally, remove
        tmp_file = fid.tmp_tif
    tmp_file.unlink(missing_ok=True)
    # !gdalinfo {dst}
    UPLOAD_TIF.append(dst)
# Out:
# WARNING:root:shape found from radius and resolution does not contain only integers: (2568.566537814864, 3316.2302581489425)
# Rounding shape to (2569, 3317) and resolution from (1001.0, 1001.0) meters to (1000.767708292762, 1000.8311032902604) meters
# Bounds: (116.226074, 34.596504, 152.5978, 56.270992)
# Extent: (-1843502.0922116844, -1277589.8005421099, 1476044.3961954073, 1293545.3038105692)
# Proj: {'datum': 'WGS84', 'lat_0': 46.120845794677734, 'lon_0': 136.46408081054688, 'proj': 'laea'}
# AreaID: nowpap_region
# ResolutionUsed: 1001.0
# SpatialResolution: 1000.0
# C:\ProgramData\Anaconda3\envs\ee\lib\site-packages\pyproj\crs\crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# resampling...
# 	 0:   chlor_a | Elapsed 4.355 sec
# 	 1:  l2_flags | Elapsed 3.852 sec
# ===========================================================================================================================================================================================================================================================================================================================
# gdal_translate -of GTiff -r nearest -ot Int32 -co TILED=YES -co COPY_SRC_OVERVIEWS=YES -co compress=lzw C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\A2022125035500.L2_LAC_OC_tmp.tif C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\A2022125035500.L2_LAC_OC.tif
# ===========================================================================================================================================================================================================================================================================================================================
# Driver: GTiff/GeoTIFF
# Files: C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\A2022125035500.L2_LAC_OC.tif
# Size is 3317, 2569
# Coordinate System is:
# PROJCRS["laea",
#     BASEGEOGCRS["WGS 84",
#         DATUM["World Geodetic System 1984",
#             ELLIPSOID["WGS 84",6378137,298.257223563,
#                 LENGTHUNIT["metre",1]]],
#         PRIMEM["Greenwich",0,
#             ANGLEUNIT["degree",0.0174532925199433]],
#         ID["EPSG",4326]],
#     CONVERSION["Lambert Azimuthal Equal Area",
#         METHOD["Lambert Azimuthal Equal Area",
#             ID["EPSG",9820]],
#         PARAMETER["Latitude of natural origin",46.1208457946777,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8801]],
#         PARAMETER["Longitude of natural origin",136.464080810547,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8802]],
#         PARAMETER["False easting",0,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8806]],
#         PARAMETER["False northing",0,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8807]]],
#     CS[Cartesian,2],
#         AXIS["(E)",east,
#             ORDER[1],
#             LENGTHUNIT["metre",1]],
#         AXIS["(N)",north,
#             ORDER[2],
#             LENGTHUNIT["metre",1]]]
# Data axis to CRS axis mapping: 1,2
# Origin = (-1843502.092211684444919,1293545.303810569224879)
# Pixel Size = (1000.767708292761995,-1000.831103290260444)
# Metadata:
#   AREA_OR_POINT=Area
#   cdm_data_type=swath
#   Conventions=CF-1.6 ACDD-1.3
#   creator_email=data@oceancolor.gsfc.nasa.gov
#   creator_name=NASA/GSFC/OBPG
#   creator_url=https://oceandata.sci.gsfc.nasa.gov
#   date_created=2022-05-20T19:24:43.000Z
#   day_night_flag=Day
#   earth_sun_distance_correction=0.9832351803779602
#   easternmost_longitude=152.5978
#   endDirection=Ascending
#   end_center_latitude=54.985657
#   end_center_longitude=132.58997
#   equatorCrossingDateTime=2022-05-05T04:34:06.094Z
#   equatorCrossingLongitude=-44.062923
#   geospatial_lat_max=56.270992
#   geospatial_lat_min=34.596504
#   geospatial_lat_units=degrees_north
#   geospatial_lon_max=152.5978
#   geospatial_lon_min=116.226074
#   geospatial_lon_units=degrees_east
#   history=l2gen par=/data5/sdpsoper/vdc/vpu4/workbuf/A2022125035500.L1B_LAC.param metafile=A2022125035500.L2_LAC_OC.nc.meta
#   id=2018.1QL/L2/A2022125035500.L2_LAC_OC.nc
#   identifier_product_doi=10.5067/AQUA/MODIS/L2/OC/2018
#   identifier_product_doi_authority=http://dx.doi.org
#   institution=NASA Goddard Space Flight Center, Ocean Ecology Laboratory, Ocean Biology Processing Group
#   instrument=MODIS
#   keywords=Earth Science > Oceans > Ocean Optics > Ocean Color
#   keywords_vocabulary=NASA Global Change Master Directory (GCMD) Science Keywords
#   license=https://science.nasa.gov/earth-science/earth-science-data/data-information-policy/
#   naming_authority=gov.nasa.gsfc.sci.oceandata
#   northernmost_latitude=56.270992
#   orbit_number=106393
#   platform=Aqua
#   processing_level=L2
#   processing_version=2018.1QL
#   product_name=A2022125035500.L2_LAC_OC.nc
#   project=Ocean Biology Processing Group (NASA/GSFC/OBPG)
#   publisher_email=data@oceancolor.gsfc.nasa.gov
#   publisher_name=NASA/GSFC/OBPG
#   publisher_url=https://oceandata.sci.gsfc.nasa.gov
#   southernmost_latitude=34.596504
#   spatialResolution=1 km
#   standard_name_vocabulary=CF Standard Name Table v36
#   startDirection=Ascending
#   start_center_latitude=37.17482
#   start_center_longitude=139.42967
#   time_coverage_end=2022-05-05T03:59:59.583Z
#   time_coverage_start=2022-05-05T03:55:01.206Z
#   title=MODISA Level-2 Data
#   westernmost_longitude=116.226074
# Image Structure Metadata:
#   COMPRESSION=LZW
#   INTERLEAVE=PIXEL
#   LAYOUT=COG
# Corner Coordinates:
# Upper Left  (-1843502.092, 1293545.304) (107d10'43.81"E, 54d32' 8.16"N)
# Lower Left  (-1843502.092,-1277589.801) (116d44' 0.84"E, 32d37'42.28"N)
# Upper Right ( 1476044.396, 1293545.304) (160d19' 5.57"E, 55d39'55.33"N)
# Lower Right ( 1476044.396,-1277589.801) (152d20'12.27"E, 33d19'47.69"N)
# Center      ( -183728.848,    7977.752) (134d 5' 4.63"E, 46d10' 4.62"N)
# Band 1 Block=256x256 Type=Int32, ColorInterp=Gray
#   Description = chlor_a
#   NoData Value=-32767
#   Overviews: 1659x1285, 830x643, 415x322, 208x161
#   Metadata:
#     chlor_a_add_offset=0.001
#     chlor_a_long_name=Chlorophyll Concentration, OCI Algorithm
#     chlor_a_reference=Hu, C., Lee Z., and Franz, B.A. (2012). Chlorophyll-a algorithms for oligotrophic oceans: A novel approach based on three-band reflectance difference, J. Geophys. Res., 117, C01011, doi:10.1029/2011JC007395.
#     chlor_a_scale_factor=1e-06
#     chlor_a_standard_name=mass_concentration_of_chlorophyll_in_sea_water
#     chlor_a_units=mg m^-3
#     chlor_a_valid_max=99929304
#     chlor_a_valid_min=0
#     chlor_a__FillValue=-32767.0
# Band 2 Block=256x256 Type=Int32, ColorInterp=Undefined
#   Description = l2_flags
#   NoData Value=-32767
#   Overviews: 1659x1285, 830x643, 415x322, 208x161
#   Metadata:
#     l2_flags_flag_masks=[          1           2           4           8          16          32
#           64         128         256         512        1024        2048
#         4096        8192       16384       32768       65536      131072
#       262144      524288     1048576     2097152     4194304     8388608
#     16777216    33554432    67108864   134217728   268435456   536870912
#   1073741824 -2147483648]
#     l2_flags_flag_meanings=ATMFAIL LAND PRODWARN HIGLINT HILT HISATZEN COASTZ SPARE STRAYLIGHT CLDICE COCCOLITH TURBIDW HISOLZEN SPARE LOWLW CHLFAIL NAVWARN ABSAER SPARE MAXAERITER MODGLINT CHLWARN ATMWARN SPARE SEAICE NAVFAIL FILTER SPARE BOWTIEDEL HIPOL PRODFAIL SPARE
#     l2_flags_long_name=Level-2 Processing Flags
#     l2_flags_valid_max=2147483647
#     l2_flags_valid_min=-2147483648
# WARNING:root:shape found from radius and resolution does not contain only integers: (8838.655143425898, 9167.331494783488)
# Rounding shape to (8839, 9168) and resolution from (251.0, 251.0) meters to (250.98169777384985, 250.99020715011883) meters
# Bounds: (123.21163, 27.046055, 146.39604, 46.45152)
# Extent: (-1050484.8314282068, -1098274.57830862, 1250515.3737624486, 1120227.8626912804)
# Proj: {'datum': 'WGS84', 'lat_0': 36.96185259015367, 'lon_0': 133.78974039904642, 'proj': 'laea'}
# AreaID: nowpap_region
# ResolutionUsed: 251.0
# SpatialResolution: 250.0
# C:\ProgramData\Anaconda3\envs\ee\lib\site-packages\pyproj\crs\crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# resampling...
# 	 0:      CHLA | Elapsed 57.708 sec
# 	 1:   QA_flag | Elapsed 56.121 sec
# ===================================================================================================================================================================================================================================================================================================================================================================
# gdal_translate -of GTiff -r nearest -ot Int32 -co TILED=YES -co COPY_SRC_OVERVIEWS=YES -co compress=lzw C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py_tmp.tif C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py.tif
# ===================================================================================================================================================================================================================================================================================================================================================================
# Driver: GTiff/GeoTIFF
# Files: C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py.tif
# Size is 9168, 8839
# Coordinate System is:
# PROJCRS["laea",
#     BASEGEOGCRS["WGS 84",
#         DATUM["World Geodetic System 1984",
#             ELLIPSOID["WGS 84",6378137,298.257223563,
#                 LENGTHUNIT["metre",1]]],
#         PRIMEM["Greenwich",0,
#             ANGLEUNIT["degree",0.0174532925199433]],
#         ID["EPSG",4326]],
#     CONVERSION["Lambert Azimuthal Equal Area",
#         METHOD["Lambert Azimuthal Equal Area",
#             ID["EPSG",9820]],
#         PARAMETER["Latitude of natural origin",36.9618525901537,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8801]],
#         PARAMETER["Longitude of natural origin",133.789740399046,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8802]],
#         PARAMETER["False easting",0,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8806]],
#         PARAMETER["False northing",0,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8807]]],
#     CS[Cartesian,2],
#         AXIS["(E)",east,
#             ORDER[1],
#             LENGTHUNIT["metre",1]],
#         AXIS["(N)",north,
#             ORDER[2],
#             LENGTHUNIT["metre",1]]]
# Data axis to CRS axis mapping: 1,2
# Origin = (-1050484.831428206758574,1120227.862691280432045)
# Pixel Size = (250.981697773849845,-250.990207150118835)
# Metadata:
#   Algorithm_developer=CHLA: Hiroshi Murakami, CDOM: Takafumi Hirata and TSM: Mitsuhiro Toratani
#   Algorithm_version=3.00
#   AREA_OR_POINT=Area
#   Dataset_description=Concentration of the green pigment in phytoplankton in surface water (CHLA) [mg m^-3], light absoption coefficient of organics dissolved in surface water at 412nm (CDOM) [m^-1] and total suspended matter concentration (TSM) [g m^-3]
#   Parameter_version=000.00
#   Product_file_name=GC1SG1_202205030152F05810_L2SG_IWPRQ_3000.h5
#   Product_level=Level-2
#   Product_name=In-water properties (IWPR)
#   Product_version=3000
#   RSP_path_number=58
#   Satellite=Global Change Observation Mission - Climate (GCOM-C)
#   Scene_center_time=20220503 01:54:23.906
#   Scene_number=10
#   Sensor=Second-generation Global Imager (SGLI)
#   time_coverage_end=2022-05-03T01:56:47.749000Z
#   time_coverage_start=2022-05-03T01:52:00.062000Z
#   Total_orbit_number=22710
# Image Structure Metadata:
#   COMPRESSION=LZW
#   INTERLEAVE=PIXEL
#   LAYOUT=COG
# Corner Coordinates:
# Upper Left  (-1050484.831, 1120227.863) (120d 6'59.79"E, 46d20'35.17"N)
# Lower Left  (-1050484.831,-1098274.578) (123d15'41.83"E, 26d33'10.86"N)
# Upper Right ( 1250515.374, 1120227.863) (150d 1' 8.54"E, 46d 2'46.47"N)
# Lower Right ( 1250515.374,-1098274.578) (146d18'42.32"E, 26d20'52.86"N)
# Center      (  100015.271,   10976.642) (134d54'51.17"E, 37d 3'19.67"N)
# Band 1 Block=256x256 Type=Int32, ColorInterp=Gray
#   Description = CHLA
#   NoData Value=-32767
#   Overviews: 4584x4420, 2292x2210, 1146x1105, 573x553, 287x277, 144x139
#   Metadata:
#     CHLA_add_offset=0.001
#     CHLA_Data_description=Chllorophyll-a concentration (CHLA) = DN * Slope + Offset [mg m^-3]
#     CHLA_Error_DN=65535
#     CHLA_Mask_for_statistics=351
#     CHLA_Maximum_valid_DN=65534
#     CHLA_Minimum_valid_DN=0
#     CHLA_scale_factor=1e-06
#     CHLA_units=mg m^-3
#     CHLA_valid_max=104407000
#     CHLA_valid_min=599
# Band 2 Block=256x256 Type=Int32, ColorInterp=Undefined
#   Description = QA_flag
#   NoData Value=-32767
#   Overviews: 4584x4420, 2292x2210, 1146x1105, 573x553, 287x277, 144x139
#   Metadata:
#     QA_flag_Data_description=Bit-0) DATAMISS: No observation data in one or more band[s],
# Bit-1) LAND: Land pixel,
# Bit-2) ATMFAIL: Atmospheric correction failure,
# Bit-3) CLDICE: Apparent cloud/ice (high reflectance),
# Bit-4) CLDAFFCTD: Cloud-affected (near-cloud or thin/sub-pixel cloud),
# Bit-5) STRAYLIGHT: Stray light anticipated (ref. L1B stray light flags & image),
# Bit-6) HIGLINT: High sun glint predicted (atmospheric corr. abandoned),
# Bit-7) MODGLINT: Moderate glint predicted (correction applied),
# Bit-8) HISOLZ: Solar zenith larger than threshold,
# Bit-9) HITAUA: Aerosol optical thickness larger than threshold,
# Bit-10) NEGNLW: Negative nLw in one or more bands,
# Bit-11) SPARE: ,
# Bit-12) SHALLOW: Shallow water than threshold,
# Bit-13) ITERFAILCDOM: Iteration failure for CDOM algorithm,
# Bit-14) CHLWARN: Chlorophyll a estimate out of range,
# Bit-15) SPARE: ,
#
#     QA_flag_Error_DN=65535
#     QA_flag_Maximum_valid_DN=65534
#     QA_flag_Minimum_valid_DN=0

# %% [markdown]
# # [EO Data Conversion Tool](https://gportal.jaxa.jp/gpr/information/tool?lang=en) resampling
# [Return to the "Table of contents"](#Contents)
#
# - Use the EO Data Conversion Tool for resampling
# Applies to GCOM-C
# > First download and install the Windows DCT tool from https://gportal.jaxa.jp/gpr/information/tool?lang=en
# > Next run the commands below

# %%
of = Path('result').absolute() # output path
for key in ('CHLA', 'QA_flag'):
    cmd = f'SGLI_geo_map_win {INPUT_FILE[-1]} -d Image_data/{key} -r 0 -o {of} -n 65535'
    print(os.popen(cmd).read())
# Out:
# ========================== Input parameters ==========================
# Input file              = sample_data\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000.h5
# Projection coordinates  = Geodetic Latitude/Longitude
# Pixel spacing           = Default (7.5sec/15sec/30sec)
# Resampling method       = NN
# Data selection          = Image_data/CHLA
# GDAL_NODATA Tag         = 65535
# Output directory        = C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result
# ======================================================================
# product_type = L2/scene
# rtype = Q
# x range =  123.2083333333,  146.4000000000
# y range =   27.0416666667,   46.4583333333
# pid = GC1SG1_202205030152F05810_L2SG_IWPRQ_3000
# map = Lat/Lon
# dataset = Image_data/CHLA
# datatype = unsigned short
# max_valid_DN = 65534
# isize = 7820/5000
# output size = 9320, 11132
# block size = 20, 20
# grid size = 467, 558
#     0/ 9340
#  2000/ 9340
#  4000/ 9340
#  6000/ 9340
#  8000/ 9340
# data resampling...
#     0/ 9320
#  2000/ 9320
#  4000/ 9320
#  6000/ 9320
#  8000/ 9320
# output = [C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_CHLA.tif]
# output = [C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_CHLA.xml]
# done...
#
# ========================== Input parameters ==========================
# Input file              = sample_data\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000.h5
# Projection coordinates  = Geodetic Latitude/Longitude
# Pixel spacing           = Default (7.5sec/15sec/30sec)
# Resampling method       = NN
# Data selection          = Image_data/QA_flag
# GDAL_NODATA Tag         = 65535
# Output directory        = C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result
# ======================================================================
# product_type = L2/scene
# rtype = Q
# x range =  123.2083333333,  146.4000000000
# y range =   27.0416666667,   46.4583333333
# pid = GC1SG1_202205030152F05810_L2SG_IWPRQ_3000
# map = Lat/Lon
# dataset = Image_data/QA_flag
# datatype = unsigned short
# max_valid_DN = 65534
# isize = 7820/5000
# output size = 9320, 11132
# block size = 20, 20
# grid size = 467, 558
#     0/ 9340
#  2000/ 9340
#  4000/ 9340
#  6000/ 9340
#  8000/ 9340
# data resampling...
#     0/ 9320
#  2000/ 9320
#  4000/ 9320
#  6000/ 9320
#  8000/ 9320
# output = [C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_QA_flag.tif]
# output = [C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_QA_flag.xml]
# done...

# %% [markdown]
# # Join [EO Data Conversion Tool](https://gportal.jaxa.jp/gpr/information/tool?lang=en) files
# [Return to the "Table of contents"](#Contents)
#
# - Combine the files created by the Earth Observation Data Conversion Tool into a single GeoTIFF
# > This step is not important. We can combine these files directly in the ingestion manifest.
# But I prefered to do it here and GDAL translate combined image.
# - This operation will also copy attributes of the original .h5 file

# %%
dst=OPATH.joinpath('GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dct.tif')
src=(OPATH.joinpath('GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_CHLA.tif'),
     OPATH.joinpath('GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_QA_flag.tif'))

with SwathResample(INPUT_FILE[1], trg_tif=dst, srs='longlat', area_id=AREA_ID) as fid:
    keys = 'CHLA', 'QA_flag'
    # open GeoTIFF file
    fid.copy_tif(bands=len(keys), src=src[0])
        
    for i, (f, key) in enumerate(zip(src, keys)):
        # Read data from file
        sds = fid.get_band(file=f)
        print(f'{i} | {f.name}: {key} | FV: {sds.fill_value}')
        # Scale data to int
        if 'CHLA' in f.name:
            # Note that CHLA is digital number. 
            # We need to scale factor the original data before scaling with the unified value for both files.
            sds *= 0.001600
        fid.data = fid.scale(key=key, data=sds)
        # output result in GeoTIFFe
        fid.append(band=i+1, key=key)
        
        # There is temporary file created internally
        tmp_file = fid.tmp_tif
        
    # translate the tif
    fid.translate()
    # remove temporary file 
    tmp_file.unlink(missing_ok=True)
    UPLOAD_TIF.append(dst)
# !gdalinfo {dst}
# Out:
# Bounds: (123.21163, 27.046055, 146.39604, 46.45152)
# Extent: (-10.57810862414409, 27.046054840087894, 12.606301471070767, 46.45151901245117)
# Proj: {'datum': 'WGS84', 'lat_0': 36.96185259015367, 'lon_0': 133.78974039904642, 'proj': 'longlat'}
# AreaID: nowpap_region
# ResolutionUsed: 250.0
# 0 | GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_CHLA.tif: CHLA | FV: 65535.0
# 1 | GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_QA_flag.tif: QA_flag | FV: 65535
# =====================================================================================================================================================================================================================================================================================================================================================================
# gdal_translate -of GTiff -r nearest -ot Int32 -co TILED=YES -co COPY_SRC_OVERVIEWS=YES -co compress=lzw C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dct_tmp.tif C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dct.tif
# =====================================================================================================================================================================================================================================================================================================================================================================
# Driver: GTiff/GeoTIFF
# Files: C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dct.tif
# Size is 11132, 9320
# Coordinate System is:
# GEOGCRS["WGS 84",
#     ENSEMBLE["World Geodetic System 1984 ensemble",
#         MEMBER["World Geodetic System 1984 (Transit)"],
#         MEMBER["World Geodetic System 1984 (G730)"],
#         MEMBER["World Geodetic System 1984 (G873)"],
#         MEMBER["World Geodetic System 1984 (G1150)"],
#         MEMBER["World Geodetic System 1984 (G1674)"],
#         MEMBER["World Geodetic System 1984 (G1762)"],
#         MEMBER["World Geodetic System 1984 (G2139)"],
#         ELLIPSOID["WGS 84",6378137,298.257223563,
#             LENGTHUNIT["metre",1]],
#         ENSEMBLEACCURACY[2.0]],
#     PRIMEM["Greenwich",0,
#         ANGLEUNIT["degree",0.0174532925199433]],
#     CS[ellipsoidal,2],
#         AXIS["geodetic latitude (Lat)",north,
#             ORDER[1],
#             ANGLEUNIT["degree",0.0174532925199433]],
#         AXIS["geodetic longitude (Lon)",east,
#             ORDER[2],
#             ANGLEUNIT["degree",0.0174532925199433]],
#     USAGE[
#         SCOPE["Horizontal component of 3D system."],
#         AREA["World."],
#         BBOX[-90,-180,90,180]],
#     ID["EPSG",4326]]
# Data axis to CRS axis mapping: 2,1
# Origin = (123.208333333333329,46.458333333333336)
# Pixel Size = (0.002083333333333,-0.002083333333333)
# Metadata:
#   Algorithm_developer=CHLA: Hiroshi Murakami, CDOM: Takafumi Hirata and TSM: Mitsuhiro Toratani
#   Algorithm_version=3.00
#   AREA_OR_POINT=Area
#   Dataset_description=Concentration of the green pigment in phytoplankton in surface water (CHLA) [mg m^-3], light absoption coefficient of organics dissolved in surface water at 412nm (CDOM) [m^-1] and total suspended matter concentration (TSM) [g m^-3]
#   Parameter_version=000.00
#   Product_file_name=GC1SG1_202205030152F05810_L2SG_IWPRQ_3000.h5
#   Product_level=Level-2
#   Product_name=In-water properties (IWPR)
#   Product_version=3000
#   RSP_path_number=58
#   Satellite=Global Change Observation Mission - Climate (GCOM-C)
#   Scene_center_time=20220503 01:54:23.906
#   Scene_number=10
#   Sensor=Second-generation Global Imager (SGLI)
#   time_coverage_end=2022-05-03T01:56:47.749000Z
#   time_coverage_start=2022-05-03T01:52:00.062000Z
#   Total_orbit_number=22710
# Image Structure Metadata:
#   COMPRESSION=LZW
#   INTERLEAVE=PIXEL
#   LAYOUT=COG
# Corner Coordinates:
# Upper Left  ( 123.2083333,  46.4583333) (123d12'30.00"E, 46d27'30.00"N)
# Lower Left  ( 123.2083333,  27.0416667) (123d12'30.00"E, 27d 2'30.00"N)
# Upper Right ( 146.4000000,  46.4583333) (146d24' 0.00"E, 46d27'30.00"N)
# Lower Right ( 146.4000000,  27.0416667) (146d24' 0.00"E, 27d 2'30.00"N)
# Center      ( 134.8041667,  36.7500000) (134d48'15.00"E, 36d45' 0.00"N)
# Band 1 Block=256x256 Type=Int32, ColorInterp=Gray
#   Description = CHLA
#   NoData Value=65535
#   Overviews: 5566x4660, 2783x2330, 1392x1165, 696x583, 348x292, 174x146
#   Metadata:
#     CHLA_add_offset=0.001
#     CHLA_Data_description=Chllorophyll-a concentration (CHLA) = DN * Slope + Offset [mg m^-3]
#     CHLA_Error_DN=65535
#     CHLA_Mask_for_statistics=351
#     CHLA_Maximum_valid_DN=65534
#     CHLA_Minimum_valid_DN=0
#     CHLA_scale_factor=1e-06
#     CHLA_units=mg m^-3
#     CHLA_valid_max=104853400
#     CHLA_valid_min=-1000
# Band 2 Block=256x256 Type=Int32, ColorInterp=Undefined
#   Description = QA_flag
#   NoData Value=65535
#   Overviews: 5566x4660, 2783x2330, 1392x1165, 696x583, 348x292, 174x146
#   Metadata:
#     QA_flag_Data_description=Bit-0) DATAMISS: No observation data in one or more band[s],
# Bit-1) LAND: Land pixel,
# Bit-2) ATMFAIL: Atmospheric correction failure,
# Bit-3) CLDICE: Apparent cloud/ice (high reflectance),
# Bit-4) CLDAFFCTD: Cloud-affected (near-cloud or thin/sub-pixel cloud),
# Bit-5) STRAYLIGHT: Stray light anticipated (ref. L1B stray light flags & image),
# Bit-6) HIGLINT: High sun glint predicted (atmospheric corr. abandoned),
# Bit-7) MODGLINT: Moderate glint predicted (correction applied),
# Bit-8) HISOLZ: Solar zenith larger than threshold,
# Bit-9) HITAUA: Aerosol optical thickness larger than threshold,
# Bit-10) NEGNLW: Negative nLw in one or more bands,
# Bit-11) SPARE: ,
# Bit-12) SHALLOW: Shallow water than threshold,
# Bit-13) ITERFAILCDOM: Iteration failure for CDOM algorithm,
# Bit-14) CHLWARN: Chlorophyll a estimate out of range,
# Bit-15) SPARE: ,
#
#     QA_flag_Error_DN=65535
#     QA_flag_Maximum_valid_DN=65534
#     QA_flag_Minimum_valid_DN=0

# %% [markdown]
# # GCloud and manifest file
# [Return to the "Table of contents"](#Contents)
#
# 1. Send file to Google Cloud bucket (or file can also be [uploaded](https://developers.google.com/earth-engine/guides/image_upload) directly into GEE)
# 2. Build ingestion manifest file
# 3. Send to GEE using Earth Engine [command-line tools](https://developers.google.com/earth-engine/guides/command_line#upload)
#
# `build_manifest` accepts the GeoTIFF file, asset_id, asset_name and uri (location of the file in the Gcloud), builds the manifest file)

# %%
def build_manifest(file, asset_id, asset_name, uri):
    """
    Writes earth engine manifest file for data upload
    manifest file name
    """

    dataset = gdal.Open(str(file), gdal.GA_ReadOnly)
    attrs = dataset.GetMetadata()
    update = attrs.update

    data = {
        "name": asset_id,
        "tilesets": [
            {'id': asset_name,
             "sources": [
                 {"uris": [uri]}
             ]}
        ],
        "start_time": attrs.pop("time_coverage_start"),
        "end_time": attrs.pop("time_coverage_end"),
        'bands': [],
        "properties": attrs
    }
    append = data['bands'].append

    for count in range(dataset.RasterCount):
        band = dataset.GetRasterBand(count + 1)
        varname = band.GetDescription()

        var_attrs = band.GetMetadata()
        update(var_attrs)
        if varname in ('QA_flag', 'l2_flags'):
            append({"id": varname,
                    'tileset_id': asset_name,
                    "pyramidingPolicy": "SAMPLE",
                    "tileset_band_index": count})
        else:
            novalue = band.GetNoDataValue()
            append({"id": varname,
                    'tileset_id': asset_name,
                    "tileset_band_index": count,
                    "pyramidingPolicy": "MEAN",
                    "missing_data": {
                        "values": [float(novalue)]}
                    })
    
    fid = Path(file).name.strip(Path(file).suffix)
    manifest = Path(f'result/{fid}_manifest.json').absolute()
    pprint(data)
    with open(manifest, 'w') as mfs:
        json.dump(data, mfs)
    return manifest

# %%
UPLOAD_TIF
# Out:
# [WindowsPath('C:/Users/Eligio/Documents/NPEC/Python/eeupload/ee-oc-data-ingestion/result/A2022125035500.L2_LAC_OC.tif'),
#  WindowsPath('C:/Users/Eligio/Documents/NPEC/Python/eeupload/ee-oc-data-ingestion/result/GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py.tif'),
#  WindowsPath('C:/Users/Eligio/Documents/NPEC/Python/eeupload/ee-oc-data-ingestion/result/GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dct.tif')]

# %%
# -------------
# GCloud upload
# -------------
for trg in UPLOAD_TIF:
    uri = f'{BUCKET}/{trg.name}'
    cmd = f'gsutil cp {trg.name} {BUCKET}'
    info = f'{"-" * len(cmd)}'
    print(f'{info}\n{cmd}\n{info}')
    # # uncomment below if bucket is defined
    # !gsutil cp {trg} {BUCKET}
# Out:
# --------------------------------------------------------------------
# gsutil cp A2022125035500.L2_LAC_OC.tif gs://ee-eutrophication-upload
# --------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# gsutil cp GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py.tif gs://ee-eutrophication-upload
# ----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# gsutil cp GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dct.tif gs://ee-eutrophication-upload
# -----------------------------------------------------------------------------------------
# Copying file://C:\Users\Eligio\Documents\NPEC\Python\eeupload\ee-oc-data-ingestion\result\A2022125035500.L2_LAC_OC.tif [Content-Type=image/tiff]...
# / [0 files][    0.0 B/  5.7 MiB]
# -
# - [0 files][  3.4 MiB/  5.7 MiB]
# - [1 files][  5.7 MiB/  5.7 MiB]
# \
#
# Operation completed over 1 objects/5.7 MiB.

# %% [markdown]
# # Build manifest and ingest files into GEE
#
# [Return to the "Table of contents"](#Contents)
#
# ## Start an authorized session
#
# To be able to upload the file into your Earth Engine asset, you need to authenticate as you when you make the request.

# %%
# import ee

# ee.Authenticate()
# ee.Initialize()

# %%
# --------------
# build manifest
# --------------
for trg in UPLOAD_TIF:
    asset_name = '_'.join(trg.name.split(trg.suffix)[0].split('.'))
    uri = f'{BUCKET}/{trg.name}'
    manifest = build_manifest(file=trg, 
                              asset_id=f'{ASSET_ID}/{asset_name}', 
                              asset_name=asset_name,
                              # asset_name=ASSET_NAME, 
                              uri=uri)
    # -----------
    # Ingest file 
    # -----------
    cmd = f'earthengine upload image --manifest {Path(manifest).name}'
    info = f'{"-" * len(cmd)}'
    print(f'{info}\n{cmd}\n{info}')
    # # uncomment as necessary
    # !earthengine upload image --manifest {manifest}
    print()
print('done..!!')
# Out:
# {'bands': [{'id': 'chlor_a',
#             'missing_data': {'values': [-32767.0]},
#             'pyramidingPolicy': 'MEAN',
#             'tileset_band_index': 0,
#             'tileset_id': 'A2022125035500_L2_LAC_OC'},
#            {'id': 'l2_flags',
#             'pyramidingPolicy': 'SAMPLE',
#             'tileset_band_index': 1,
#             'tileset_id': 'A2022125035500_L2_LAC_OC'}],
#  'end_time': '2022-05-05T03:59:59.583Z',
#  'name': 'projects/ee-eutrophicationwatch/assets/OCEANDATA/L2/Test/A2022125035500_L2_LAC_OC',
#  'properties': {'AREA_OR_POINT': 'Area',
#                 'Conventions': 'CF-1.6 ACDD-1.3',
#                 'cdm_data_type': 'swath',
#                 'chlor_a__FillValue': '-32767.0',
#                 'chlor_a_add_offset': '0.001',
#                 'chlor_a_long_name': 'Chlorophyll Concentration, OCI Algorithm',
#                 'chlor_a_reference': 'Hu, C., Lee Z., and Franz, B.A. (2012). '
#                                      'Chlorophyll-a algorithms for '
#                                      'oligotrophic oceans: A novel approach '
#                                      'based on three-band reflectance '
#                                      'difference, J. Geophys. Res., 117, '
#                                      'C01011, doi:10.1029/2011JC007395.',
#                 'chlor_a_scale_factor': '1e-06',
#                 'chlor_a_standard_name': 'mass_concentration_of_chlorophyll_in_sea_water',
#                 'chlor_a_units': 'mg m^-3',
#                 'chlor_a_valid_max': '99929304',
#                 'chlor_a_valid_min': '0',
#                 'creator_email': 'data@oceancolor.gsfc.nasa.gov',
#                 'creator_name': 'NASA/GSFC/OBPG',
#                 'creator_url': 'https://oceandata.sci.gsfc.nasa.gov',
#                 'date_created': '2022-05-20T19:24:43.000Z',
#                 'day_night_flag': 'Day',
#                 'earth_sun_distance_correction': '0.9832351803779602',
#                 'easternmost_longitude': '152.5978',
#                 'endDirection': 'Ascending',
#                 'end_center_latitude': '54.985657',
#                 'end_center_longitude': '132.58997',
#                 'equatorCrossingDateTime': '2022-05-05T04:34:06.094Z',
#                 'equatorCrossingLongitude': '-44.062923',
#                 'geospatial_lat_max': '56.270992',
#                 'geospatial_lat_min': '34.596504',
#                 'geospatial_lat_units': 'degrees_north',
#                 'geospatial_lon_max': '152.5978',
#                 'geospatial_lon_min': '116.226074',
#                 'geospatial_lon_units': 'degrees_east',
#                 'history': 'l2gen '
#                            'par=/data5/sdpsoper/vdc/vpu4/workbuf/A2022125035500.L1B_LAC.param '
#                            'metafile=A2022125035500.L2_LAC_OC.nc.meta',
#                 'id': '2018.1QL/L2/A2022125035500.L2_LAC_OC.nc',
#                 'identifier_product_doi': '10.5067/AQUA/MODIS/L2/OC/2018',
#                 'identifier_product_doi_authority': 'http://dx.doi.org',
#                 'institution': 'NASA Goddard Space Flight Center, Ocean '
#                                'Ecology Laboratory, Ocean Biology Processing '
#                                'Group',
#                 'instrument': 'MODIS',
#                 'keywords': 'Earth Science > Oceans > Ocean Optics > Ocean '
#                             'Color',
#                 'keywords_vocabulary': 'NASA Global Change Master Directory '
#                                        '(GCMD) Science Keywords',
#                 'l2_flags_flag_masks': '[          1           2           '
#                                        '4           8          16          32\n'
#                                        '          64         128         '
#                                        '256         512        1024        '
#                                        '2048\n'
#                                        '        4096        8192       '
#                                        '16384       32768       65536      '
#                                        '131072\n'
#                                        '      262144      524288     '
#                                        '1048576     2097152     4194304     '
#                                        '8388608\n'
#                                        '    16777216    33554432    67108864   '
#                                        '134217728   268435456   536870912\n'
#                                        '  1073741824 -2147483648]',
#                 'l2_flags_flag_meanings': 'ATMFAIL LAND PRODWARN HIGLINT HILT '
#                                           'HISATZEN COASTZ SPARE STRAYLIGHT '
#                                           'CLDICE COCCOLITH TURBIDW HISOLZEN '
#                                           'SPARE LOWLW CHLFAIL NAVWARN ABSAER '
#                                           'SPARE MAXAERITER MODGLINT CHLWARN '
#                                           'ATMWARN SPARE SEAICE NAVFAIL FILTER '
#                                           'SPARE BOWTIEDEL HIPOL PRODFAIL '
#                                           'SPARE',
#                 'l2_flags_long_name': 'Level-2 Processing Flags',
#                 'l2_flags_valid_max': '2147483647',
#                 'l2_flags_valid_min': '-2147483648',
#                 'license': 'https://science.nasa.gov/earth-science/earth-science-data/data-information-policy/',
#                 'naming_authority': 'gov.nasa.gsfc.sci.oceandata',
#                 'northernmost_latitude': '56.270992',
#                 'orbit_number': '106393',
#                 'platform': 'Aqua',
#                 'processing_level': 'L2',
#                 'processing_version': '2018.1QL',
#                 'product_name': 'A2022125035500.L2_LAC_OC.nc',
#                 'project': 'Ocean Biology Processing Group (NASA/GSFC/OBPG)',
#                 'publisher_email': 'data@oceancolor.gsfc.nasa.gov',
#                 'publisher_name': 'NASA/GSFC/OBPG',
#                 'publisher_url': 'https://oceandata.sci.gsfc.nasa.gov',
#                 'southernmost_latitude': '34.596504',
#                 'spatialResolution': '1 km',
#                 'standard_name_vocabulary': 'CF Standard Name Table v36',
#                 'startDirection': 'Ascending',
#                 'start_center_latitude': '37.17482',
#                 'start_center_longitude': '139.42967',
#                 'title': 'MODISA Level-2 Data',
#                 'westernmost_longitude': '116.226074'},
#  'start_time': '2022-05-05T03:55:01.206Z',
#  'tilesets': [{'id': 'A2022125035500_L2_LAC_OC',
#                'sources': [{'uris': ['gs://ee-eutrophication-upload/A2022125035500.L2_LAC_OC.tif']}]}]}
# --------------------------------------------------------------------------
# earthengine upload image --manifest A2022125035500.L2_LAC_OC_manifest.json
# --------------------------------------------------------------------------
# Started upload task with ID: S5GUQ6R6JXO43V7W63TF2JY4
#
# {'bands': [{'id': 'CHLA',
#             'missing_data': {'values': [-32767.0]},
#             'pyramidingPolicy': 'MEAN',
#             'tileset_band_index': 0,
#             'tileset_id': 'GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py'},
#            {'id': 'QA_flag',
#             'pyramidingPolicy': 'SAMPLE',
#             'tileset_band_index': 1,
#             'tileset_id': 'GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py'}],
#  'end_time': '2022-05-03T01:56:47.749000Z',
#  'name': 'projects/ee-eutrophicationwatch/assets/OCEANDATA/L2/Test/GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py',
#  'properties': {'AREA_OR_POINT': 'Area',
#                 'Algorithm_developer': 'CHLA: Hiroshi Murakami, CDOM: Takafumi '
#                                        'Hirata and TSM: Mitsuhiro Toratani',
#                 'Algorithm_version': '3.00',
#                 'CHLA_Data_description': 'Chllorophyll-a concentration (CHLA) '
#                                          '= DN * Slope + Offset [mg m^-3]',
#                 'CHLA_Error_DN': '65535',
#                 'CHLA_Mask_for_statistics': '351',
#                 'CHLA_Maximum_valid_DN': '65534',
#                 'CHLA_Minimum_valid_DN': '0',
#                 'CHLA_add_offset': '0.001',
#                 'CHLA_scale_factor': '1e-06',
#                 'CHLA_units': 'mg m^-3',
#                 'CHLA_valid_max': '104407000',
#                 'CHLA_valid_min': '599',
#                 'Dataset_description': 'Concentration of the green pigment in '
#                                        'phytoplankton in surface water (CHLA) '
#                                        '[mg m^-3], light absoption coefficient '
#                                        'of organics dissolved in surface water '
#                                        'at 412nm (CDOM) [m^-1] and total '
#                                        'suspended matter concentration (TSM) '
#                                        '[g m^-3]',
#                 'Parameter_version': '000.00',
#                 'Product_file_name': 'GC1SG1_202205030152F05810_L2SG_IWPRQ_3000.h5',
#                 'Product_level': 'Level-2',
#                 'Product_name': 'In-water properties (IWPR)',
#                 'Product_version': '3000',
#                 'QA_flag_Data_description': 'Bit-0) DATAMISS: No observation '
#                                             'data in one or more band[s],\n'
#                                             'Bit-1) LAND: Land pixel,\n'
#                                             'Bit-2) ATMFAIL: Atmospheric '
#                                             'correction failure,\n'
#                                             'Bit-3) CLDICE: Apparent cloud/ice '
#                                             '(high reflectance),\n'
#                                             'Bit-4) CLDAFFCTD: Cloud-affected '
#                                             '(near-cloud or thin/sub-pixel '
#                                             'cloud),\n'
#                                             'Bit-5) STRAYLIGHT: Stray light '
#                                             'anticipated (ref. L1B stray light '
#                                             'flags & image),\n'
#                                             'Bit-6) HIGLINT: High sun glint '
#                                             'predicted (atmospheric corr. '
#                                             'abandoned),\n'
#                                             'Bit-7) MODGLINT: Moderate glint '
#                                             'predicted (correction applied),\n'
#                                             'Bit-8) HISOLZ: Solar zenith '
#                                             'larger than threshold,\n'
#                                             'Bit-9) HITAUA: Aerosol optical '
#                                             'thickness larger than threshold,\n'
#                                             'Bit-10) NEGNLW: Negative nLw in '
#                                             'one or more bands,\n'
#                                             'Bit-11) SPARE: ,\n'
#                                             'Bit-12) SHALLOW: Shallow water '
#                                             'than threshold,\n'
#                                             'Bit-13) ITERFAILCDOM: Iteration '
#                                             'failure for CDOM algorithm,\n'
#                                             'Bit-14) CHLWARN: Chlorophyll a '
#                                             'estimate out of range,\n'
#                                             'Bit-15) SPARE: ,\n',
#                 'QA_flag_Error_DN': '65535',
#                 'QA_flag_Maximum_valid_DN': '65534',
#                 'QA_flag_Minimum_valid_DN': '0',
#                 'RSP_path_number': '58',
#                 'Satellite': 'Global Change Observation Mission - Climate '
#                              '(GCOM-C)',
#                 'Scene_center_time': '20220503 01:54:23.906',
#                 'Scene_number': '10',
#                 'Sensor': 'Second-generation Global Imager (SGLI)',
#                 'Total_orbit_number': '22710'},
#  'start_time': '2022-05-03T01:52:00.062000Z',
#  'tilesets': [{'id': 'GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py',
#                'sources': [{'uris': ['gs://ee-eutrophication-upload/GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py.tif']}]}]}
# ----------------------------------------------------------------------------------------------
# earthengine upload image --manifest GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_py_manifest.json
# ----------------------------------------------------------------------------------------------
#
# {'bands': [{'id': 'CHLA',
#             'missing_data': {'values': [65535.0]},
#             'pyramidingPolicy': 'MEAN',
#             'tileset_band_index': 0,
#             'tileset_id': 'GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dct'},
#            {'id': 'QA_flag',
#             'pyramidingPolicy': 'SAMPLE',
#             'tileset_band_index': 1,
#             'tileset_id': 'GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dct'}],
#  'end_time': '2022-05-03T01:56:47.749000Z',
#  'name': 'projects/ee-eutrophicationwatch/assets/OCEANDATA/L2/Test/GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dct',
#  'properties': {'AREA_OR_POINT': 'Area',
#                 'Algorithm_developer': 'CHLA: Hiroshi Murakami, CDOM: Takafumi '
#                                        'Hirata and TSM: Mitsuhiro Toratani',
#                 'Algorithm_version': '3.00',
#                 'CHLA_Data_description': 'Chllorophyll-a concentration (CHLA) '
#                                          '= DN * Slope + Offset [mg m^-3]',
#                 'CHLA_Error_DN': '65535',
#                 'CHLA_Mask_for_statistics': '351',
#                 'CHLA_Maximum_valid_DN': '65534',
#                 'CHLA_Minimum_valid_DN': '0',
#                 'CHLA_add_offset': '0.001',
#                 'CHLA_scale_factor': '1e-06',
#                 'CHLA_units': 'mg m^-3',
#                 'CHLA_valid_max': '104853400',
#                 'CHLA_valid_min': '-1000',
#                 'Dataset_description': 'Concentration of the green pigment in '
#                                        'phytoplankton in surface water (CHLA) '
#                                        '[mg m^-3], light absoption coefficient '
#                                        'of organics dissolved in surface water '
#                                        'at 412nm (CDOM) [m^-1] and total '
#                                        'suspended matter concentration (TSM) '
#                                        '[g m^-3]',
#                 'Parameter_version': '000.00',
#                 'Product_file_name': 'GC1SG1_202205030152F05810_L2SG_IWPRQ_3000.h5',
#                 'Product_level': 'Level-2',
#                 'Product_name': 'In-water properties (IWPR)',
#                 'Product_version': '3000',
#                 'QA_flag_Data_description': 'Bit-0) DATAMISS: No observation '
#                                             'data in one or more band[s],\n'
#                                             'Bit-1) LAND: Land pixel,\n'
#                                             'Bit-2) ATMFAIL: Atmospheric '
#                                             'correction failure,\n'
#                                             'Bit-3) CLDICE: Apparent cloud/ice '
#                                             '(high reflectance),\n'
#                                             'Bit-4) CLDAFFCTD: Cloud-affected '
#                                             '(near-cloud or thin/sub-pixel '
#                                             'cloud),\n'
#                                             'Bit-5) STRAYLIGHT: Stray light '
#                                             'anticipated (ref. L1B stray light '
#                                             'flags & image),\n'
#                                             'Bit-6) HIGLINT: High sun glint '
#                                             'predicted (atmospheric corr. '
#                                             'abandoned),\n'
#                                             'Bit-7) MODGLINT: Moderate glint '
#                                             'predicted (correction applied),\n'
#                                             'Bit-8) HISOLZ: Solar zenith '
#                                             'larger than threshold,\n'
#                                             'Bit-9) HITAUA: Aerosol optical '
#                                             'thickness larger than threshold,\n'
#                                             'Bit-10) NEGNLW: Negative nLw in '
#                                             'one or more bands,\n'
#                                             'Bit-11) SPARE: ,\n'
#                                             'Bit-12) SHALLOW: Shallow water '
#                                             'than threshold,\n'
#                                             'Bit-13) ITERFAILCDOM: Iteration '
#                                             'failure for CDOM algorithm,\n'
#                                             'Bit-14) CHLWARN: Chlorophyll a '
#                                             'estimate out of range,\n'
#                                             'Bit-15) SPARE: ,\n',
#                 'QA_flag_Error_DN': '65535',
#                 'QA_flag_Maximum_valid_DN': '65534',
#                 'QA_flag_Minimum_valid_DN': '0',
#                 'RSP_path_number': '58',
#                 'Satellite': 'Global Change Observation Mission - Climate '
#                              '(GCOM-C)',
#                 'Scene_center_time': '20220503 01:54:23.906',
#                 'Scene_number': '10',
#                 'Sensor': 'Second-generation Global Imager (SGLI)',
#                 'Total_orbit_number': '22710'},
#  'start_time': '2022-05-03T01:52:00.062000Z',
#  'tilesets': [{'id': 'GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dct',
#                'sources': [{'uris': ['gs://ee-eutrophication-upload/GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dct.tif']}]}]}
# ----------------------------------------------------------------------------------------------
# earthengine upload image --manifest GC1SG1_202205030152F05810_L2SG_IWPRQ_3000_dc_manifest.json
# ----------------------------------------------------------------------------------------------
#
# done..!!
